# %% [markdown]
# <a href="https://colab.research.google.com/github/Chhavi0926/DS_45_InternshipDays/blob/main/DAY_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Basic code of python.
print("Hello")
# Out:
# Hello

# %%
print('Hii')
print('This is my first code in python')
# Out:
# Hii
# This is my first code in python

# %%
print('Hii,This is my first code in python')
# Out:
# Hii,This is my first code in python

# %% [markdown]
# **# Variables** -- It is the container which stores the values.

# %%
Name = 'Chhavi Chhipa'
Age = 20
Subject = 'DS/ML'
Marks = 90.95
# Here Name,Age,Subject,Marks are the variables.And their respective values are Chhavi Chhipa,20,DS/ML,90.95.
print(Name)
# Out:
# Chhavi Chhipa

# %%
print(Age)
print(Subject)
print(Marks)
# Out:
# 20
# DS/ML
# 90.95

# %%
Subject12 = Subject
print(Subject12)
# Out:
# DS/ML

# %%
print(Name,Age,Subject,Marks)
# Out:
# Chhavi Chhipa 20 DS/ML 90.95

# %%
print('My name is :',Name)
print('My age is :',Age)
print('My subject is :',Subject)
print('My marks are :',Marks)
# Out:
# My name is : Chhavi Chhipa
# My age is : 20
# My subject is : DS/ML
# My marks are : 90.95

# %%
print('My name is :',Name,'. My age is :',Age)
# Out:
# My name is : Chhavi Chhipa . My age is : 20

# %% [markdown]
# **#Datatypes** -- 1. Integers  2. Float 3. String 4. Boolean 5. None

# %%
print(type(Name))
print(type(Age))
print(type(Subject))
print(type(Marks))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
Age = 20
old = False
a = None
print(type(old))
print(type(a))
# Out:
# <class 'bool'>
# <class 'NoneType'>

# %% [markdown]
# **Sum of numbers**

# %%
a = 28
b = 53
sum = a+b
print('Sum of a and b is :',sum)
# Out:
# Sum of a and b is : 81

# %% [markdown]
# **Without using third variable.**

# %%
print('Sum is :', a+b)
# Out:
# Sum is : 81

# %% [markdown]
# **Types of Operators**
# Arithmetic,Comparison(Relational),Assignment,Logical,Bitwise,Identity,Membership are the names of operators.

# %%
# 1. Arithmetic operators -- (+,-.*,/,//,%,**)
a = 4
b = 2
print('Addition :',a+b)
print('Subtraction :',a-b)
print('Multiplication :',a*b)
print('Division :',a/b)
print('Floor Division :',a//b)
print('Modulus :',a%b)    # Remender
print('Exponent :',a**b)  # a^b
# Out:
# Addition : 6
# Subtraction : 2
# Multiplication : 8
# Division : 2.0
# Floor Division : 2
# Modulus : 0
# Exponent : 16
